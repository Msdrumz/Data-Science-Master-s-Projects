# %%
import pandas as pd

# %%
airline_data = pd.read_csv('/Users/peytonbailey/WGU Data Science Masters/D602 - Deployment/Task 2/d602-deployment-task-2/airport_data.csv', on_bad_lines='skip')

# %%
print(airline_data.head())
airline_data.info
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  \
# 0  2025      1             1            3    ABQ  BUR          1600    1606.0
# 1  2025      1             1            3    ABQ  LAX           600     552.0
# 2  2025      1             1            3    ABQ  LAX           645     643.0
# 3  2025      1             1            3    ABQ  LAX          1335    1340.0
# 4  2025      1             1            3    ABQ  LAX          1500    1452.0
#
#    DEP_DELAY  CRS_ARR_TIME  ARR_TIME  ARR_DELAY
# 0        6.0          1710    1658.0      -12.0
# 1       -8.0           728     710.0      -18.0
# 2       -2.0           804     744.0      -20.0
# 3        5.0          1445    1444.0       -1.0
# 4       -8.0          1623    1604.0      -19.0
# <bound method DataFrame.info of         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK ORIGIN DEST  CRS_DEP_TIME  \
# 0       2025      1             1            3    ABQ  BUR          1600
# ...

# %%
airline_data.to_csv('processed_data.csv')
